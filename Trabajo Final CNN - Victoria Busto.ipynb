# %% [markdown]
# # Style Transfer
#
# <img src="https://i0.wp.com/chelseatroy.com/wp-content/uploads/2018/12/neural_style_transfer.png?resize=768%2C311&ssl=1">
#
# La idea de este trabajo final es reproducir el siguiente paper:
#
# https://arxiv.org/pdf/1508.06576.pdf
#
# El objetivo es transferir el estilo de una imagen dada a otra imagen distinta.
#
# Como hemos visto en clase, las primeras capas de una red convolucional se activan ante la presencia de ciertos patrones vinculados a detalles muy pequeños.
#
# A medida que avanzamos en las distintas capas de una red neuronal convolucional, los filtros se van activando a medida que detectan patrones de formas cada vez mas complejos.
#
# Lo que propone este paper es asignarle a la activación de las primeras capas de una red neuronal convolucional (por ejemplo VGG19) la definición del estilo y a la activación de las últimas capas de la red neuronal convolucional, la definición del contenido.
#
# La idea de este paper es, a partir de dos imágenes (una que aporte el estilo y otra que aporte el contenido) analizar cómo es la activación de las primeras capas para la imagen que aporta el estilo y cómo es la activación de las últimas capas de la red convolucional para la imagen que aporta el contenido. A partir de esto se intentará sintetizar una imagen que active los filtros de las primeras capas que se activaron con la imagen que aporta el estilo y los filtros de las últimas capas que se activaron con la imagen que aporta el contenido.
#
# A este procedimiento se lo denomina neural style transfer.
#
# # En este trabajo se deberá leer el paper mencionado y en base a ello, entender la implementación que se muestra a continuación y contestar preguntas sobre la misma.
#
# # Una metodología posible es hacer una lectura rápida del paper (aunque esto signifique no entender algunos detalles del mismo) y luego ir analizando el código y respondiendo las preguntas. A medida que se planteen las preguntas, volviendo a leer secciones específicas del paper terminará de entender los detalles que pudieran haber quedado pendientes.
#
# Lo primero que haremos es cargar dos imágenes, una que aporte el estilo y otra que aporte el contenido. A tal fin utilizaremos imágenes disponibles en la web.

# %%
# Imagen para estilo
#!wget https://upload.wikimedia.org/wikipedia/commons/5/52/La_noche_estrellada1.jpg

#!wget https://commons.wikimedia.org/wiki/File:Guernica_Rathaus_PF.jpg#/media/File:Guernica_Rathaus_PF.jpg

#!wget https://upload.wikimedia.org/wikipedia/commons/c/cc/Juan_Miró%2C_Landscape_%28The_Grasshopper%29_1926%3B_oil%2C_Goulandris_Museum%2C_Athens.jpg
# Imagen para contenido
#!wget https://upload.wikimedia.org/wikipedia/commons/thumb/f/f4/Neckarfront_T%C3%BCbingen_Mai_2017.jpg/775px-Neckarfront_T%C3%BCbingen_Mai_2017.jpg

#!wget https://upload.wikimedia.org/wikipedia/en/4/4c/Les_Demoiselles_d%27Avignon.jpg

# Creamos el directorio para los archivos de salida
#!mkdir /content/output
# Out:
# --2020-06-20 19:08:55--  https://upload.wikimedia.org/wikipedia/commons/5/52/La_noche_estrellada1.jpg
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 91.198.174.208, 2620:0:862:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|91.198.174.208|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 223725 (218K) [image/jpeg]
# Saving to: ‘La_noche_estrellada1.jpg.1’
#
# La_noche_estrellada 100%[===================>] 218.48K  --.-KB/s    in 0.02s
#
# 2020-06-20 19:08:55 (13.4 MB/s) - ‘La_noche_estrellada1.jpg.1’ saved [223725/223725]
#
# --2020-06-20 19:08:57--  https://commons.wikimedia.org/wiki/File:Guernica_Rathaus_PF.jpg
# Resolving commons.wikimedia.org (commons.wikimedia.org)... 91.198.174.192, 2620:0:861:ed1a::1
# Connecting to commons.wikimedia.org (commons.wikimedia.org)|91.198.174.192|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘File:Guernica_Rathaus_PF.jpg.1’
#
# File:Guernica_Ratha     [ <=>                ]  39.21K  --.-KB/s    in 0.006s
#
# 2020-06-20 19:08:57 (6.58 MB/s) - ‘File:Guernica_Rathaus_PF.jpg.1’ saved [40153]
#
# --2020-06-20 19:09:00--  https://upload.wikimedia.org/wikipedia/commons/c/cc/Juan_Mir%C3%B3%2C_Landscape_%28The_Grasshopper%29_1926%3B_oil%2C_Goulandris_Museum%2C_Athens.jpg
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 91.198.174.208, 2620:0:862:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|91.198.174.208|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 908882 (888K) [image/jpeg]
# Saving to: ‘Juan_Miró,_Landscape_(The_Grasshopper)_1926;_oil,_Goulandris_Museum,_Athens.jpg.1’
#
# Juan_Miró,_Landscap 100%[===================>] 887.58K  --.-KB/s    in 0.04s
#
# 2020-06-20 19:09:00 (22.6 MB/s) - ‘Juan_Miró,_Landscape_(The_Grasshopper)_1926;_oil,_Goulandris_Museum,_Athens.jpg.1’ saved [908882/908882]
#
# --2020-06-20 19:09:03--  https://upload.wikimedia.org/wikipedia/commons/thumb/f/f4/Neckarfront_T%C3%BCbingen_Mai_2017.jpg/775px-Neckarfront_T%C3%BCbingen_Mai_2017.jpg
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 91.198.174.208, 2620:0:862:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|91.198.174.208|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 153015 (149K) [image/jpeg]
# Saving to: ‘775px-Neckarfront_Tübingen_Mai_2017.jpg.1’
#
# 775px-Neckarfront_T 100%[===================>] 149.43K  --.-KB/s    in 0.01s
#
# 2020-06-20 19:09:03 (10.4 MB/s) - ‘775px-Neckarfront_Tübingen_Mai_2017.jpg.1’ saved [153015/153015]
#
# mkdir: cannot create directory ‘/content/output’: File exists

# %%
from keras.preprocessing.image import load_img, save_img, img_to_array
import numpy as np
from scipy.optimize import fmin_l_bfgs_b
import time
import argparse

from keras.applications import vgg19
from keras import backend as K
from pathlib import Path

# %%
# Definimos las imagenes que vamos a utilizar, y el directorio de salida

# !mkdir /output
result_prefix = Path("/output")


base_image_path = Path("/input/775px-Neckarfront_Tübingen_Mai_2017.jpg")
style_reference_image_path = Path("/input/La_noche_estrellada1.jpg")

#definimos paths para la pregunta 9
style_reference_image_path_2 = Path("/input/Les_Demoiselles_d'Avignon.jpg")
base_image_path_2 = Path("/input/sol_2.jpg")

# %% [markdown]
# # 1) En base a lo visto en el paper ¿Qué significan los parámetros definidos en la siguiente celda?
#
# **Respuesta:**
#
# En base a lo leido en el paper, se entiende que la loss a minimizar para la generación de las imagenes, se encuentra definido por 2 tipos de losses: una de estilo (style) y otra de contenido (content). Los parametros *Style Weight* y *Content Weight* son los pesos que tiene cada loss. Cuando se pone un peso muy grande en Content Weight, se puede identificar bien la fotografia, pero el estilo de la pintura no coinside. Con lo cual existe un trade-off entre cada una de las losses y por ende de los pesos.
# Dentro del calculo de la loss por estilo, el *Total Variation Weight* es la contribucion de cada capa a la loss total.

# %%
iterations = 100
total_variation_weight = 0.1
style_weight = 10
content_weight = 1

# %%
# Definimos el tamaño de las imágenes a utilizar
width, height = load_img(base_image_path).size
img_nrows = 400
img_ncols = int(width * img_nrows / height)

# %% [markdown]
# # 2) Explicar qué hace la siguiente celda. En especial las últimas dos líneas de la función antes del return. ¿Por qué?
#
# Ayuda: https://keras.io/applications/
#
# **Respuesta:**
# La funcion lo que hace es:
#
#
# 1. Carga la imagen y define un formato de target
# 2. Transforma la imagen al formato de Python array (tensor)
# 3. Agrega una dimensión al comienzo del array (tensor) de numpy. porque? Porque las redes neuronales esperan que la primer dimension del array (tensor) corresponda al nro de batches.
# 4. Aplica el modelo pre-entrenado por ImageNet y aplica el comando preprocess?input que lo que hace es convertir el tensor en una imagen valida. La funcion recive un array y lo que hace es convertir la imagen de RGB a VGR y centra cada color en 0 con respecto a la base de datos de ImageNet.

# %%
def preprocess_image(image_path):
    img = load_img(image_path, target_size=(img_nrows, img_ncols))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = vgg19.preprocess_input(img)
    return img

# %% [markdown]
# # 3) Habiendo comprendido lo que hace la celda anterior, explique de manera muy concisa qué hace la siguiente celda. ¿Qué relación tiene con la celda anterior?
#
# **Respuesta:** la funcion lo que hace es volver a procer la iamgen para transformala con el formato original. Por lo tanto, se le resetea el centro de los colores para que deje de estar centrado en 0 y se pasa la medición de colores de BGR a RGB.
#
# La funcion primero hace un reshape de la imagen, para luego sumarle los escalares para que los colores dejen de estar 0 centrados. Luego pasa primer dimención del canal BGR a la ultima posicion y la ultima posicion a la primera, para quedar en RGB

# %%
def deprocess_image(x):
    x = x.reshape((img_nrows, img_ncols, 3))
    # Remove zero-center by mean pixel
    x[:, :, 0] += 103.939
    x[:, :, 1] += 116.779
    x[:, :, 2] += 123.68
    # 'BGR'->'RGB'
    x = x[:, :, ::-1]
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
# get tensor representations of our images
# K.variable convierte un numpy array en un tensor, para 
base_image = K.variable(preprocess_image(base_image_path))
style_reference_image = K.variable(preprocess_image(style_reference_image_path))

# %%
combination_image = K.placeholder((1, img_nrows, img_ncols, 3))

# %% [markdown]
# Aclaración:
#
# La siguiente celda sirve para procesar las tres imagenes (contenido, estilo y salida) en un solo batch.

# %%
# combine the 3 images into a single Keras tensor
input_tensor = K.concatenate([base_image,
                              style_reference_image,
                              combination_image], axis=0)

# %%
# build the VGG19 network with our 3 images as input
# the model will be loaded with pre-trained ImageNet weights
model = vgg19.VGG19(input_tensor=input_tensor,
                    weights='imagenet', include_top=False)
print('Model loaded.')

# get the symbolic outputs of each "key" layer (we gave them unique names).
outputs_dict = dict([(layer.name, layer.output) for layer in model.layers])
# Out:
# Model loaded.

# %% [markdown]
# # 4) En la siguientes celdas:
#
# - **¿Qué es la matriz de Gram?¿Para qué se usa?** La matriz Gram muestra la correlacion entre los diferentes filtros de una capa. Se utiliza para calcular la contribucion de cada capa a la loss de estilo. Es decir, al minimizar las distancias cuadradas medias de las entradas de la matriz Gram de la imagen original  y de la matriz Gram de la imagen generada se obtiene la contribucion de cada capa a la loss de estilo.
# - **¿Por qué se permutan las dimensiones de x?** Se permutan las dimensiones del vector de entrada de la matriz Gram para que queden en el orden RGB.

# %%
def gram_matrix(x):
    features = K.batch_flatten(K.permute_dimensions(x, (2, 0, 1)))
    gram = K.dot(features, K.transpose(features))
    return gram

# %% [markdown]
# # 5) Losses:
#
# Explicar qué mide cada una de las losses en las siguientes tres celdas.
#
# **Respuesta:**
#
#
# *   **Style Loss:** Mide la diferencia entre la imagen original y la imagen creada con estilos en cada capa. Esta loss se calcula por medio de la minimización de la distancia media al cuadrado de las matrices de Gram (uso de correlaciones) para cada una de las imagenes. Esta loss se encuentra afectada por un factor que indica cuanto afecta cada estilo a la loss total.
# *  **Content Loss:** Mide el error cuadratico medio entre la imagen original y la imagen generada en cada capa. En esta loss lo que se busca hacer es un Content Reconstructions, donde se recontruye la imagen orginal utilizando solamente la respuesta de la red en las diferentes capas.
# *  **Total Variation Loss:** Es la combinacion lineal de las 2 losses (Style y Content Loss) multiplicado por 2 factores (weights) alfa y beta que ponderan el peso de cada una de las losses.

# %%
def style_loss(style, combination):
    assert K.ndim(style) == 3
    assert K.ndim(combination) == 3
    S = gram_matrix(style)
    C = gram_matrix(combination)
    channels = 3
    size = img_nrows * img_ncols
    return K.sum(K.square(S - C)) / (4.0 * (channels ** 2) * (size ** 2))

# %%
def content_loss(base, combination):
    return K.sum(K.square(combination - base))

# %%
def total_variation_loss(x):
    assert K.ndim(x) == 4
    a = K.square(
        x[:, :img_nrows - 1, :img_ncols - 1, :] - x[:, 1:, :img_ncols - 1, :])
    b = K.square(
        x[:, :img_nrows - 1, :img_ncols - 1, :] - x[:, :img_nrows - 1, 1:, :])
    return K.sum(K.pow(a + b, 1.25))

# %%
# Armamos la loss total
loss = K.variable(0.0)
layer_features = outputs_dict['block5_conv2']
base_image_features = layer_features[0, :, :, :]
combination_features = layer_features[2, :, :, :]
loss = loss + content_weight * content_loss(base_image_features,
                                              combination_features)

feature_layers = ['block1_conv1', 'block2_conv1',
                    'block3_conv1', 'block4_conv1',
                    'block5_conv1']
for layer_name in feature_layers:
  layer_features = outputs_dict[layer_name]
  style_reference_features = layer_features[1, :, :, :] 
  combination_features = layer_features[2, :, :, :]
  sl = style_loss(style_reference_features, combination_features)
  loss = loss + (style_weight / len(feature_layers)) * sl
loss = loss + total_variation_weight * total_variation_loss(combination_image)

# %%
grads = K.gradients(loss, combination_image)

outputs = [loss]
if isinstance(grads, (list, tuple)):
    outputs += grads
else:
    outputs.append(grads)

f_outputs = K.function([combination_image], outputs)

# %% [markdown]
# # 6) Explique el propósito de las siguientes tres celdas. ¿Qué hace la función fmin_l_bfgs_b? ¿En qué se diferencia con la implementación del paper? ¿Se puede utilizar alguna alternativa?
#
# **Respuesta:**
#
# La celda que comienza con *class Evaluator(object)* define las funciones dentro de la clase Evaluator para obtener los resultados de la loss y los valores de los gradientes.
#
# La celda que comienza con *def eval_loss_and_grads(x):*  toma en base a un input X la loss y los gradientes.
#
# La funcion *fmin_l_bfgs_b* lo que hace es minimizar una funcion por medio de la implementacion del algoritmo L-BFGS-B.

# %%
def eval_loss_and_grads(x):
    x = x.reshape((1, img_nrows, img_ncols, 3))
    outs = f_outputs([x])
    loss_value = outs[0]
    if len(outs[1:]) == 1:
        grad_values = outs[1].flatten().astype('float64')
    else:
        grad_values = np.array(outs[1:]).flatten().astype('float64')
    return loss_value, grad_values

# this Evaluator class makes it possible
# to compute loss and gradients in one pass
# while retrieving them via two separate functions,
# "loss" and "grads". This is done because scipy.optimize
# requires separate functions for loss and gradients,
# but computing them separately would be inefficient.

# %%
class Evaluator(object):

    def __init__(self):
        self.loss_value = None
        self.grads_values = None

    def loss(self, x):
        assert self.loss_value is None
        loss_value, grad_values = eval_loss_and_grads(x)
        self.loss_value = loss_value
        self.grad_values = grad_values
        return self.loss_value

    def grads(self, x):
        assert self.loss_value is not None
        grad_values = np.copy(self.grad_values)
        self.loss_value = None
        self.grad_values = None
        return grad_values

# %% [markdown]
# # 7) Ejecute la siguiente celda y observe las imágenes de salida en cada iteración.
#
# <img src="images\pregunta_7.jpeg">
#
#
# Como se puede ver en la imagen adjunta, a medida que se incrementan las iteraciones el algoritmo logra reducir la loss y ajustar la imagen al estilo del cuadro.
#
# En la primera iteración se ven algunas modificaciones en las lineas, y a medida que aumentan las interacion se observa la predominancia del estilo del cuadro. Notemos que los colores cambian y se acentuan los cielos y estilo caracteristico de los cuadros de Van Gogh.
#
# Recordemos que los pesos de la loss de estilo es de 10 mientras que de la loss de contenido se encuentre en 1.

# %%
# !mkdir /output_7
result_prefix = Path("/output_7")


evaluator = Evaluator()

# run scipy-based optimization (L-BFGS) over the pixels of the generated image
# so as to minimize the neural style loss
x = preprocess_image(base_image_path)

for i in range(iterations):
    print('Start of iteration', i)
    start_time = time.time()
    x, min_val, info = fmin_l_bfgs_b(evaluator.loss, x.flatten(),
                                     fprime=evaluator.grads, maxfun=20)
    print('Current loss value:', min_val)
    # save current generated image
    img = deprocess_image(x.copy())
    fname = result_prefix / ('output_at_iteration_%d.png' % i)
    save_img(fname, img)
    end_time = time.time()
    print('Image saved as', fname)
    print('Iteration %d completed in %ds' % (i, end_time - start_time))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Start of iteration 0
# Current loss value: 13279711000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_0.png
# Iteration 0 completed in 3s
# Start of iteration 1
# Current loss value: 6407108600.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_1.png
# Iteration 1 completed in 3s
# Start of iteration 2
# Current loss value: 4333841400.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_2.png
# Iteration 2 completed in 3s
# Start of iteration 3
# Current loss value: 3362596900.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_3.png
# Iteration 3 completed in 3s
# Start of iteration 4
# Current loss value: 2763554000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_4.png
# Iteration 4 completed in 3s
# Start of iteration 5
# Current loss value: 2310964200.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_5.png
# Iteration 5 completed in 3s
# Start of iteration 6
# Current loss value: 2089875300.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_6.png
# Iteration 6 completed in 3s
# Start of iteration 7
# Current loss value: 1877100800.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_7.png
# Iteration 7 completed in 3s
# Start of iteration 8
# Current loss value: 1765276800.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_8.png
# Iteration 8 completed in 3s
# Start of iteration 9
# Current loss value: 1594344100.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_9.png
# Iteration 9 completed in 4s
# Start of iteration 10
# Current loss value: 1522395600.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_10.png
# Iteration 10 completed in 3s
# Start of iteration 11
# Current loss value: 1475362400.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_11.png
# Iteration 11 completed in 3s
# Start of iteration 12
# Current loss value: 1436585500.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_12.png
# Iteration 12 completed in 3s
# Start of iteration 13
# Current loss value: 1373777900.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_13.png
# Iteration 13 completed in 4s
# Start of iteration 14
# Current loss value: 1329477100.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_14.png
# Iteration 14 completed in 3s
# Start of iteration 15
# Current loss value: 1302289400.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_15.png
# Iteration 15 completed in 3s
# Start of iteration 16
# Current loss value: 1279798800.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_16.png
# Iteration 16 completed in 3s
# Start of iteration 17
# Current loss value: 1257552400.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_17.png
# Iteration 17 completed in 3s
# Start of iteration 18
# Current loss value: 1237474600.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_18.png
# Iteration 18 completed in 4s
# Start of iteration 19
# Current loss value: 1220117100.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_19.png
# Iteration 19 completed in 4s
# Start of iteration 20
# Current loss value: 1206222500.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_20.png
# Iteration 20 completed in 3s
# Start of iteration 21
# Current loss value: 1190772400.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_21.png
# Iteration 21 completed in 4s
# Start of iteration 22
# Current loss value: 1178027000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_22.png
# Iteration 22 completed in 4s
# Start of iteration 23
# Current loss value: 1168727200.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_23.png
# Iteration 23 completed in 3s
# Start of iteration 24
# Current loss value: 1159138000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_24.png
# Iteration 24 completed in 3s
# Start of iteration 25
# Current loss value: 1150292200.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_25.png
# Iteration 25 completed in 3s
# Start of iteration 26
# Current loss value: 1139278200.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_26.png
# Iteration 26 completed in 4s
# Start of iteration 27
# Current loss value: 1130073100.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_27.png
# Iteration 27 completed in 3s
# Start of iteration 28
# Current loss value: 1122336600.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_28.png
# Iteration 28 completed in 3s
# Start of iteration 29
# Current loss value: 1115597000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_29.png
# Iteration 29 completed in 3s
# Start of iteration 30
# Current loss value: 1109249500.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_30.png
# Iteration 30 completed in 3s
# Start of iteration 31
# Current loss value: 1100552700.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_31.png
# Iteration 31 completed in 3s
# Start of iteration 32
# Current loss value: 1092350700.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_32.png
# Iteration 32 completed in 4s
# Start of iteration 33
# Current loss value: 1084957700.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_33.png
# Iteration 33 completed in 4s
# Start of iteration 34
# Current loss value: 1076758400.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_34.png
# Iteration 34 completed in 3s
# Start of iteration 35
# Current loss value: 1070687940.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_35.png
# Iteration 35 completed in 3s
# Start of iteration 36
# Current loss value: 1064337900.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_36.png
# Iteration 36 completed in 3s
# Start of iteration 37
# Current loss value: 1055633340.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_37.png
# Iteration 37 completed in 4s
# Start of iteration 38
# Current loss value: 1049051000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_38.png
# Iteration 38 completed in 3s
# Start of iteration 39
# Current loss value: 1043163500.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_39.png
# Iteration 39 completed in 4s
# Start of iteration 40
# Current loss value: 1038020200.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_40.png
# Iteration 40 completed in 4s
# Start of iteration 41
# Current loss value: 1034124400.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_41.png
# Iteration 41 completed in 3s
# Start of iteration 42
# Current loss value: 1030901760.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_42.png
# Iteration 42 completed in 3s
# Start of iteration 43
# Current loss value: 1027706000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_43.png
# Iteration 43 completed in 3s
# Start of iteration 44
# Current loss value: 1024518900.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_44.png
# Iteration 44 completed in 3s
# Start of iteration 45
# Current loss value: 1020809340.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_45.png
# Iteration 45 completed in 4s
# Start of iteration 46
# Current loss value: 1017217860.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_46.png
# Iteration 46 completed in 4s
# Start of iteration 47
# Current loss value: 1013983040.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_47.png
# Iteration 47 completed in 4s
# Start of iteration 48
# Current loss value: 1011018500.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_48.png
# Iteration 48 completed in 4s
# Start of iteration 49
# Current loss value: 1008054900.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_49.png
# Iteration 49 completed in 3s
# Start of iteration 50
# Current loss value: 1005328640.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_50.png
# Iteration 50 completed in 3s
# Start of iteration 51
# Current loss value: 1002409860.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_51.png
# Iteration 51 completed in 4s
# Start of iteration 52
# Current loss value: 998695940.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_52.png
# Iteration 52 completed in 4s
# Start of iteration 53
# Current loss value: 995950460.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_53.png
# Iteration 53 completed in 3s
# Start of iteration 54
# Current loss value: 993271500.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_54.png
# Iteration 54 completed in 4s
# Start of iteration 55
# Current loss value: 990965760.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_55.png
# Iteration 55 completed in 3s
# Start of iteration 56
# Current loss value: 987570700.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_56.png
# Iteration 56 completed in 4s
# Start of iteration 57
# Current loss value: 984444000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_57.png
# Iteration 57 completed in 3s
# Start of iteration 58
# Current loss value: 981551000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_58.png
# Iteration 58 completed in 4s
# Start of iteration 59
# Current loss value: 978885250.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_59.png
# Iteration 59 completed in 3s
# Start of iteration 60
# Current loss value: 976443460.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_60.png
# Iteration 60 completed in 3s
# Start of iteration 61
# Current loss value: 973952640.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_61.png
# Iteration 61 completed in 4s
# Start of iteration 62
# Current loss value: 972208000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_62.png
# Iteration 62 completed in 3s
# Start of iteration 63
# Current loss value: 970123500.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_63.png
# Iteration 63 completed in 3s
# Start of iteration 64
# Current loss value: 967999500.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_64.png
# Iteration 64 completed in 3s
# Start of iteration 65
# Current loss value: 965943400.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_65.png
# Iteration 65 completed in 3s
# Start of iteration 66
# Current loss value: 963832500.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_66.png
# Iteration 66 completed in 3s
# Start of iteration 67
# Current loss value: 961707460.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_67.png
# Iteration 67 completed in 3s
# Start of iteration 68
# Current loss value: 959799800.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_68.png
# Iteration 68 completed in 3s
# Start of iteration 69
# Current loss value: 957720200.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_69.png
# Iteration 69 completed in 4s
# Start of iteration 70
# Current loss value: 955762240.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_70.png
# Iteration 70 completed in 4s
# Start of iteration 71
# Current loss value: 954272800.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_71.png
# Iteration 71 completed in 4s
# Start of iteration 72
# Current loss value: 952310300.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_72.png
# Iteration 72 completed in 4s
# Start of iteration 73
# Current loss value: 950448260.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_73.png
# Iteration 73 completed in 4s
# Start of iteration 74
# Current loss value: 948621300.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_74.png
# Iteration 74 completed in 3s
# Start of iteration 75
# Current loss value: 946485900.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_75.png
# Iteration 75 completed in 4s
# Start of iteration 76
# Current loss value: 944185200.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_76.png
# Iteration 76 completed in 3s
# Start of iteration 77
# Current loss value: 942378900.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_77.png
# Iteration 77 completed in 4s
# Start of iteration 78
# Current loss value: 940412500.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_78.png
# Iteration 78 completed in 4s
# Start of iteration 79
# Current loss value: 939003200.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_79.png
# Iteration 79 completed in 4s
# Start of iteration 80
# Current loss value: 937754560.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_80.png
# Iteration 80 completed in 4s
# Start of iteration 81
# Current loss value: 936573250.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_81.png
# Iteration 81 completed in 3s
# Start of iteration 82
# Current loss value: 935419500.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_82.png
# Iteration 82 completed in 3s
# Start of iteration 83
# Current loss value: 933972200.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_83.png
# Iteration 83 completed in 3s
# Start of iteration 84
# Current loss value: 932662800.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_84.png
# Iteration 84 completed in 3s
# Start of iteration 85
# Current loss value: 931421600.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_85.png
# Iteration 85 completed in 3s
# Start of iteration 86
# Current loss value: 929841000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_86.png
# Iteration 86 completed in 4s
# Start of iteration 87
# Current loss value: 928531460.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_87.png
# Iteration 87 completed in 3s
# Start of iteration 88
# Current loss value: 927100900.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_88.png
# Iteration 88 completed in 3s
# Start of iteration 89
# Current loss value: 925793300.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_89.png
# Iteration 89 completed in 4s
# Start of iteration 90
# Current loss value: 924378240.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_90.png
# Iteration 90 completed in 3s
# Start of iteration 91
# Current loss value: 922871400.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_91.png
# Iteration 91 completed in 4s
# Start of iteration 92
# Current loss value: 921145340.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_92.png
# Iteration 92 completed in 4s
# Start of iteration 93
# Current loss value: 920255300.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_93.png
# Iteration 93 completed in 3s
# Start of iteration 94
# Current loss value: 919168830.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_94.png
# Iteration 94 completed in 4s
# Start of iteration 95
# Current loss value: 918178800.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_95.png
# Iteration 95 completed in 3s
# Start of iteration 96
# Current loss value: 917121300.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_96.png
# Iteration 96 completed in 4s
# Start of iteration 97
# Current loss value: 916126460.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_97.png
# Iteration 97 completed in 3s
# Start of iteration 98
# Current loss value: 915252200.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_98.png
# Iteration 98 completed in 3s
# Start of iteration 99
# Current loss value: 914349800.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_7/output_at_iteration_99.png
# Iteration 99 completed in 3s

# %% [markdown]
# # 8) Generar imágenes para distintas combinaciones de pesos de las losses. Explicar las diferencias. (Adjuntar las imágenes generadas como archivos separados.)
#
# Respuesta:
#
# Para realizar esta prueba, se iteraron los pesos de estilo y contenido sobre 3 valores 0, 1 y 100 para lograr obtener resultados bien diferenciados entre los pesos. Con el fin de simplificar el proceso, se redujo el número de interaciones en cada caso. Además, se armo una matriz para comparar los resultados obtenidos en las combinaciones propuestas tomando la utlima interacion del proceso.
#
# <img src="images\pregunta_8.jpeg">
#
#
#
# Cuando el peso del estilo y de contenido son igual a 0, la imagen que se genera solo se ve afectada por el factor de la loss total. Por ende, la resultante es una imagen borrosa.
#
# Cuando el peso de estilo es 0 y se comienza a incrementar el peso de contenido, se observa que la imagen generada conserva la estructura de la fotografia. Los colores generados son mas bien pixelados y las figuras conservan bien su estructura geométrica.
#
# En el caso en el que el peso de la estructura es igual a 0 y se comienza a incrementar el peso del estilo, se observa que la fotografia se distorsiona para adaptarse al estilo del cuadro de Van Gogh. Notemos que las lineas de las casas dejan de ser rectas para pasar a ser las lineas caracteristicas del pintor.
#
# Cuando se varian ambos pesos, se observa que tanto los colores como la estructura de la imagen comienza a compensarse y toma tanto de la fotografía como del estilo del cuadro.

# %%
evaluator = Evaluator()
# Creamos el directorio para los archivos de salida
# !mkdir /output_8
result_prefix = Path("/output_8")

iterations =20
# run scipy-based optimization (L-BFGS) over the pixels of the generated image
# so as to minimize the neural style loss
x = preprocess_image(base_image_path)

for sw in [0,1,100]:
  style_weight = sw
  for cw in [0,1,100]:
    content_weight = cw
    for i in range(iterations):
      print('Start Style Weight', sw)
      print('Start Content Weight', cw) 
      print('Start of iteration', i)
      start_time = time.time()

      loss = K.variable(0.0)
      layer_features = outputs_dict['block5_conv2']
      base_image_features = layer_features[0, :, :, :]
      combination_features = layer_features[2, :, :, :]
      loss = loss + content_weight * content_loss(base_image_features,
                                              combination_features)
      feature_layers = ['block1_conv1', 'block2_conv1',
                    'block3_conv1', 'block4_conv1',
                    'block5_conv1']
      for layer_name in feature_layers:
        layer_features = outputs_dict[layer_name]
        style_reference_features = layer_features[1, :, :, :] 
        combination_features = layer_features[2, :, :, :]
        sl = style_loss(style_reference_features, combination_features)
        loss = loss + (style_weight / len(feature_layers)) * sl
      loss = loss + total_variation_weight * total_variation_loss(combination_image)

      grads = K.gradients(loss, combination_image)
      outputs = [loss]
      if isinstance(grads, (list, tuple)):
        outputs += grads
      else:
        outputs.append(grads)
      f_outputs = K.function([combination_image], outputs)

      x, min_val, info = fmin_l_bfgs_b(evaluator.loss, x.flatten(),
                                     fprime=evaluator.grads, maxfun=20)
      print('Current loss value:', min_val)
      # save current generated image
      img = deprocess_image(x.copy())
      fname = result_prefix / ('salida_8_iteration_%d_%d_%d.png' % (sw,cw,i))
      print('Image saved as', fname)
      save_img(fname, img)
      end_time = time.time()
      print('Image saved as', fname)
      print('Iteration %d completed in %ds' % (i, end_time - start_time))
# Out:
# Start Style Weight 0
# Start Content Weight 0
# Start of iteration 0
# Current loss value: 3080104.2
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_0_0.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_0_0.png
# Iteration 0 completed in 20s
# Start Style Weight 0
# Start Content Weight 0
# Start of iteration 1
# Current loss value: 500149.4
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_0_1.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_0_1.png
# Iteration 1 completed in 11s
# Start Style Weight 0
# Start Content Weight 0
# Start of iteration 2
# Current loss value: 196525.58
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_0_2.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_0_2.png
# Iteration 2 completed in 12s
# Start Style Weight 0
# Start Content Weight 0
# Start of iteration 3
# Current loss value: 114398.89
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_0_3.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_0_3.png
# Iteration 3 completed in 12s
# Start Style Weight 0
# Start Content Weight 0
# Start of iteration 4
# Current loss value: 73905.086
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_0_4.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_0_4.png
# Iteration 4 completed in 12s
# Start Style Weight 0
# Start Content Weight 0
# Start of iteration 5
# Current loss value: 54631.508
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_0_5.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_0_5.png
# Iteration 5 completed in 12s
# Start Style Weight 0
# Start Content Weight 0
# Start of iteration 6
# Current loss value: 39000.863
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_0_6.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_0_6.png
# Iteration 6 completed in 12s
# Start Style Weight 0
# Start Content Weight 0
# Start of iteration 7
# Current loss value: 30620.094
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_0_7.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_0_7.png
# Iteration 7 completed in 12s
# Start Style Weight 0
# Start Content Weight 0
# Start of iteration 8
# Current loss value: 25177.309
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_0_8.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_0_8.png
# Iteration 8 completed in 12s
# Start Style Weight 0
# Start Content Weight 0
# Start of iteration 9
# Current loss value: 21624.365
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_0_9.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_0_9.png
# Iteration 9 completed in 12s
# Start Style Weight 0
# Start Content Weight 0
# Start of iteration 10
# Current loss value: 18987.467
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_0_10.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_0_10.png
# Iteration 10 completed in 12s
# Start Style Weight 0
# Start Content Weight 0
# Start of iteration 11
# Current loss value: 17139.092
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_0_11.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_0_11.png
# Iteration 11 completed in 12s
# Start Style Weight 0
# Start Content Weight 0
# Start of iteration 12
# Current loss value: 15127.733
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_0_12.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_0_12.png
# Iteration 12 completed in 12s
# Start Style Weight 0
# Start Content Weight 0
# Start of iteration 13
# Current loss value: 13697.275
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_0_13.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_0_13.png
# Iteration 13 completed in 12s
# Start Style Weight 0
# Start Content Weight 0
# Start of iteration 14
# Current loss value: 12025.619
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_0_14.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_0_14.png
# Iteration 14 completed in 12s
# Start Style Weight 0
# Start Content Weight 0
# Start of iteration 15
# Current loss value: 10907.721
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_0_15.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_0_15.png
# Iteration 15 completed in 13s
# Start Style Weight 0
# Start Content Weight 0
# Start of iteration 16
# Current loss value: 9940.187
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_0_16.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_0_16.png
# Iteration 16 completed in 13s
# Start Style Weight 0
# Start Content Weight 0
# Start of iteration 17
# Current loss value: 9254.7705
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_0_17.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_0_17.png
# Iteration 17 completed in 14s
# Start Style Weight 0
# Start Content Weight 0
# Start of iteration 18
# Current loss value: 8705.827
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_0_18.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_0_18.png
# Iteration 18 completed in 13s
# Start Style Weight 0
# Start Content Weight 0
# Start of iteration 19
# Current loss value: 8266.065
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_0_19.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_0_19.png
# Iteration 19 completed in 14s
# Start Style Weight 0
# Start Content Weight 1
# Start of iteration 0
# Current loss value: 916995650.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_1_0.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_1_0.png
# Iteration 0 completed in 14s
# Start Style Weight 0
# Start Content Weight 1
# Start of iteration 1
# Current loss value: 347837200.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_1_1.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_1_1.png
# Iteration 1 completed in 14s
# Start Style Weight 0
# Start Content Weight 1
# Start of iteration 2
# Current loss value: 213627200.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_1_2.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_1_2.png
# Iteration 2 completed in 14s
# Start Style Weight 0
# Start Content Weight 1
# Start of iteration 3
# Current loss value: 162703100.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_1_3.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_1_3.png
# Iteration 3 completed in 14s
# Start Style Weight 0
# Start Content Weight 1
# Start of iteration 4
# Current loss value: 135794930.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_1_4.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_1_4.png
# Iteration 4 completed in 14s
# Start Style Weight 0
# Start Content Weight 1
# Start of iteration 5
# Current loss value: 119574590.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_1_5.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_1_5.png
# Iteration 5 completed in 15s
# Start Style Weight 0
# Start Content Weight 1
# Start of iteration 6
# Current loss value: 108983816.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_1_6.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_1_6.png
# Iteration 6 completed in 15s
# Start Style Weight 0
# Start Content Weight 1
# Start of iteration 7
# Current loss value: 101902590.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_1_7.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_1_7.png
# Iteration 7 completed in 16s
# Start Style Weight 0
# Start Content Weight 1
# Start of iteration 8
# Current loss value: 96578510.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_1_8.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_1_8.png
# Iteration 8 completed in 16s
# Start Style Weight 0
# Start Content Weight 1
# Start of iteration 9
# Current loss value: 92519510.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_1_9.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_1_9.png
# Iteration 9 completed in 16s
# Start Style Weight 0
# Start Content Weight 1
# Start of iteration 10
# Current loss value: 89313470.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_1_10.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_1_10.png
# Iteration 10 completed in 16s
# Start Style Weight 0
# Start Content Weight 1
# Start of iteration 11
# Current loss value: 86650080.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_1_11.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_1_11.png
# Iteration 11 completed in 17s
# Start Style Weight 0
# Start Content Weight 1
# Start of iteration 12
# Current loss value: 84264350.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_1_12.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_1_12.png
# Iteration 12 completed in 17s
# Start Style Weight 0
# Start Content Weight 1
# Start of iteration 13
# Current loss value: 82235260.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_1_13.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_1_13.png
# Iteration 13 completed in 17s
# Start Style Weight 0
# Start Content Weight 1
# Start of iteration 14
# Current loss value: 80528980.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_1_14.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_1_14.png
# Iteration 14 completed in 18s
# Start Style Weight 0
# Start Content Weight 1
# Start of iteration 15
# Current loss value: 79059280.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_1_15.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_1_15.png
# Iteration 15 completed in 18s
# Start Style Weight 0
# Start Content Weight 1
# Start of iteration 16
# Current loss value: 77763970.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_1_16.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_1_16.png
# Iteration 16 completed in 19s
# Start Style Weight 0
# Start Content Weight 1
# Start of iteration 17
# Current loss value: 76640980.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_1_17.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_1_17.png
# Iteration 17 completed in 19s
# Start Style Weight 0
# Start Content Weight 1
# Start of iteration 18
# Current loss value: 75632740.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_1_18.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_1_18.png
# Iteration 18 completed in 19s
# Start Style Weight 0
# Start Content Weight 1
# Start of iteration 19
# Current loss value: 74723280.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_1_19.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_1_19.png
# Iteration 19 completed in 19s
# Start Style Weight 0
# Start Content Weight 100
# Start of iteration 0
# Current loss value: 3261445400.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_100_0.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_100_0.png
# Iteration 0 completed in 21s
# Start Style Weight 0
# Start Content Weight 100
# Start of iteration 1
# Current loss value: 2836108500.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_100_1.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_100_1.png
# Iteration 1 completed in 21s
# Start Style Weight 0
# Start Content Weight 100
# Start of iteration 2
# Current loss value: 2581918500.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_100_2.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_100_2.png
# Iteration 2 completed in 20s
# Start Style Weight 0
# Start Content Weight 100
# Start of iteration 3
# Current loss value: 2410242800.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_100_3.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_100_3.png
# Iteration 3 completed in 21s
# Start Style Weight 0
# Start Content Weight 100
# Start of iteration 4
# Current loss value: 2253431300.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_100_4.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_100_4.png
# Iteration 4 completed in 21s
# Start Style Weight 0
# Start Content Weight 100
# Start of iteration 5
# Current loss value: 2121671400.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_100_5.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_100_5.png
# Iteration 5 completed in 21s
# Start Style Weight 0
# Start Content Weight 100
# Start of iteration 6
# Current loss value: 2010966000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_100_6.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_100_6.png
# Iteration 6 completed in 21s
# Start Style Weight 0
# Start Content Weight 100
# Start of iteration 7
# Current loss value: 1921052200.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_100_7.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_100_7.png
# Iteration 7 completed in 22s
# Start Style Weight 0
# Start Content Weight 100
# Start of iteration 8
# Current loss value: 1839345700.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_100_8.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_100_8.png
# Iteration 8 completed in 22s
# Start Style Weight 0
# Start Content Weight 100
# Start of iteration 9
# Current loss value: 1770386400.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_100_9.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_100_9.png
# Iteration 9 completed in 23s
# Start Style Weight 0
# Start Content Weight 100
# Start of iteration 10
# Current loss value: 1714452500.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_100_10.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_100_10.png
# Iteration 10 completed in 24s
# Start Style Weight 0
# Start Content Weight 100
# Start of iteration 11
# Current loss value: 1658538800.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_100_11.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_100_11.png
# Iteration 11 completed in 24s
# Start Style Weight 0
# Start Content Weight 100
# Start of iteration 12
# Current loss value: 1608379300.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_100_12.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_100_12.png
# Iteration 12 completed in 25s
# Start Style Weight 0
# Start Content Weight 100
# Start of iteration 13
# Current loss value: 1561953800.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_100_13.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_100_13.png
# Iteration 13 completed in 25s
# Start Style Weight 0
# Start Content Weight 100
# Start of iteration 14
# Current loss value: 1521672400.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_100_14.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_100_14.png
# Iteration 14 completed in 26s
# Start Style Weight 0
# Start Content Weight 100
# Start of iteration 15
# Current loss value: 1487606500.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_100_15.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_100_15.png
# Iteration 15 completed in 26s
# Start Style Weight 0
# Start Content Weight 100
# Start of iteration 16
# Current loss value: 1453655900.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_100_16.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_100_16.png
# Iteration 16 completed in 27s
# Start Style Weight 0
# Start Content Weight 100
# Start of iteration 17
# Current loss value: 1423326300.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_100_17.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_100_17.png
# Iteration 17 completed in 27s
# Start Style Weight 0
# Start Content Weight 100
# Start of iteration 18
# Current loss value: 1394636000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_100_18.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_100_18.png
# Iteration 18 completed in 28s
# Start Style Weight 0
# Start Content Weight 100
# Start of iteration 19
# Current loss value: 1369569400.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_100_19.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_0_100_19.png
# Iteration 19 completed in 29s
# Start Style Weight 1
# Start Content Weight 0
# Start of iteration 0
# Current loss value: 1725007200.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_0_0.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_0_0.png
# Iteration 0 completed in 26s
# Start Style Weight 1
# Start Content Weight 0
# Start of iteration 1
# Current loss value: 972172000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_0_1.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_0_1.png
# Iteration 1 completed in 27s
# Start Style Weight 1
# Start Content Weight 0
# Start of iteration 2
# Current loss value: 709782000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_0_2.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_0_2.png
# Iteration 2 completed in 28s
# Start Style Weight 1
# Start Content Weight 0
# Start of iteration 3
# Current loss value: 602040300.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_0_3.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_0_3.png
# Iteration 3 completed in 28s
# Start Style Weight 1
# Start Content Weight 0
# Start of iteration 4
# Current loss value: 524526850.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_0_4.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_0_4.png
# Iteration 4 completed in 29s
# Start Style Weight 1
# Start Content Weight 0
# Start of iteration 5
# Current loss value: 470352200.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_0_5.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_0_5.png
# Iteration 5 completed in 30s
# Start Style Weight 1
# Start Content Weight 0
# Start of iteration 6
# Current loss value: 429520450.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_0_6.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_0_6.png
# Iteration 6 completed in 31s
# Start Style Weight 1
# Start Content Weight 0
# Start of iteration 7
# Current loss value: 411318500.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_0_7.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_0_7.png
# Iteration 7 completed in 31s
# Start Style Weight 1
# Start Content Weight 0
# Start of iteration 8
# Current loss value: 398086200.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_0_8.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_0_8.png
# Iteration 8 completed in 32s
# Start Style Weight 1
# Start Content Weight 0
# Start of iteration 9
# Current loss value: 388309920.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_0_9.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_0_9.png
# Iteration 9 completed in 33s
# Start Style Weight 1
# Start Content Weight 0
# Start of iteration 10
# Current loss value: 380374270.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_0_10.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_0_10.png
# Iteration 10 completed in 33s
# Start Style Weight 1
# Start Content Weight 0
# Start of iteration 11
# Current loss value: 366765340.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_0_11.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_0_11.png
# Iteration 11 completed in 34s
# Start Style Weight 1
# Start Content Weight 0
# Start of iteration 12
# Current loss value: 359338750.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_0_12.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_0_12.png
# Iteration 12 completed in 35s
# Start Style Weight 1
# Start Content Weight 0
# Start of iteration 13
# Current loss value: 355626700.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_0_13.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_0_13.png
# Iteration 13 completed in 36s
# Start Style Weight 1
# Start Content Weight 0
# Start of iteration 14
# Current loss value: 352276480.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_0_14.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_0_14.png
# Iteration 14 completed in 37s
# Start Style Weight 1
# Start Content Weight 0
# Start of iteration 15
# Current loss value: 348940740.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_0_15.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_0_15.png
# Iteration 15 completed in 38s
# Start Style Weight 1
# Start Content Weight 0
# Start of iteration 16
# Current loss value: 346258900.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_0_16.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_0_16.png
# Iteration 16 completed in 38s
# Start Style Weight 1
# Start Content Weight 0
# Start of iteration 17
# Current loss value: 343781100.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_0_17.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_0_17.png
# Iteration 17 completed in 39s
# Start Style Weight 1
# Start Content Weight 0
# Start of iteration 18
# Current loss value: 341113950.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_0_18.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_0_18.png
# Iteration 18 completed in 40s
# Start Style Weight 1
# Start Content Weight 0
# Start of iteration 19
# Current loss value: 338867940.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_0_19.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_0_19.png
# Iteration 19 completed in 41s
# Start Style Weight 1
# Start Content Weight 1
# Start of iteration 0
# Current loss value: 1027596600.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_1_0.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_1_0.png
# Iteration 0 completed in 42s
# Start Style Weight 1
# Start Content Weight 1
# Start of iteration 1
# Current loss value: 833237250.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_1_1.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_1_1.png
# Iteration 1 completed in 44s
# Start Style Weight 1
# Start Content Weight 1
# Start of iteration 2
# Current loss value: 757905200.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_1_2.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_1_2.png
# Iteration 2 completed in 45s
# Start Style Weight 1
# Start Content Weight 1
# Start of iteration 3
# Current loss value: 712652200.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_1_3.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_1_3.png
# Iteration 3 completed in 46s
# Start Style Weight 1
# Start Content Weight 1
# Start of iteration 4
# Current loss value: 684591360.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_1_4.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_1_4.png
# Iteration 4 completed in 47s
# Start Style Weight 1
# Start Content Weight 1
# Start of iteration 5
# Current loss value: 664715460.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_1_5.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_1_5.png
# Iteration 5 completed in 48s
# Start Style Weight 1
# Start Content Weight 1
# Start of iteration 6
# Current loss value: 651382300.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_1_6.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_1_6.png
# Iteration 6 completed in 49s
# Start Style Weight 1
# Start Content Weight 1
# Start of iteration 7
# Current loss value: 639755500.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_1_7.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_1_7.png
# Iteration 7 completed in 49s
# Start Style Weight 1
# Start Content Weight 1
# Start of iteration 8
# Current loss value: 630371000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_1_8.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_1_8.png
# Iteration 8 completed in 51s
# Start Style Weight 1
# Start Content Weight 1
# Start of iteration 9
# Current loss value: 622522600.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_1_9.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_1_9.png
# Iteration 9 completed in 52s
# Start Style Weight 1
# Start Content Weight 1
# Start of iteration 10
# Current loss value: 616381900.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_1_10.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_1_10.png
# Iteration 10 completed in 53s
# Start Style Weight 1
# Start Content Weight 1
# Start of iteration 11
# Current loss value: 610978370.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_1_11.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_1_11.png
# Iteration 11 completed in 51s
# Start Style Weight 1
# Start Content Weight 1
# Start of iteration 12
# Current loss value: 605877250.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_1_12.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_1_12.png
# Iteration 12 completed in 53s
# Start Style Weight 1
# Start Content Weight 1
# Start of iteration 13
# Current loss value: 601192640.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_1_13.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_1_13.png
# Iteration 13 completed in 54s
# Start Style Weight 1
# Start Content Weight 1
# Start of iteration 14
# Current loss value: 596620300.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_1_14.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_1_14.png
# Iteration 14 completed in 55s
# Start Style Weight 1
# Start Content Weight 1
# Start of iteration 15
# Current loss value: 592650500.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_1_15.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_1_15.png
# Iteration 15 completed in 54s
# Start Style Weight 1
# Start Content Weight 1
# Start of iteration 16
# Current loss value: 589056260.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_1_16.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_1_16.png
# Iteration 16 completed in 55s
# Start Style Weight 1
# Start Content Weight 1
# Start of iteration 17
# Current loss value: 585633700.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_1_17.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_1_17.png
# Iteration 17 completed in 56s
# Start Style Weight 1
# Start Content Weight 1
# Start of iteration 18
# Current loss value: 582609900.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_1_18.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_1_18.png
# Iteration 18 completed in 57s
# Start Style Weight 1
# Start Content Weight 1
# Start of iteration 19
# Current loss value: 580037700.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_1_19.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_1_19.png
# Iteration 19 completed in 57s
# Start Style Weight 1
# Start Content Weight 100
# Start of iteration 0
# Current loss value: 11655654000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_100_0.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_100_0.png
# Iteration 0 completed in 58s
# Start Style Weight 1
# Start Content Weight 100
# Start of iteration 1
# Current loss value: 9417660000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_100_1.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_100_1.png
# Iteration 1 completed in 59s
# Start Style Weight 1
# Start Content Weight 100
# Start of iteration 2
# Current loss value: 8098531300.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_100_2.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_100_2.png
# Iteration 2 completed in 60s
# Start Style Weight 1
# Start Content Weight 100
# Start of iteration 3
# Current loss value: 7312583700.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_100_3.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_100_3.png
# Iteration 3 completed in 62s
# Start Style Weight 1
# Start Content Weight 100
# Start of iteration 4
# Current loss value: 6839122400.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_100_4.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_100_4.png
# Iteration 4 completed in 63s
# Start Style Weight 1
# Start Content Weight 100
# Start of iteration 5
# Current loss value: 6501727700.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_100_5.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_100_5.png
# Iteration 5 completed in 63s
# Start Style Weight 1
# Start Content Weight 100
# Start of iteration 6
# Current loss value: 6213797000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_100_6.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_100_6.png
# Iteration 6 completed in 65s
# Start Style Weight 1
# Start Content Weight 100
# Start of iteration 7
# Current loss value: 5994379300.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_100_7.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_100_7.png
# Iteration 7 completed in 65s
# Start Style Weight 1
# Start Content Weight 100
# Start of iteration 8
# Current loss value: 5818680300.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_100_8.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_100_8.png
# Iteration 8 completed in 67s
# Start Style Weight 1
# Start Content Weight 100
# Start of iteration 9
# Current loss value: 5670219300.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_100_9.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_100_9.png
# Iteration 9 completed in 68s
# Start Style Weight 1
# Start Content Weight 100
# Start of iteration 10
# Current loss value: 5547645000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_100_10.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_100_10.png
# Iteration 10 completed in 69s
# Start Style Weight 1
# Start Content Weight 100
# Start of iteration 11
# Current loss value: 5443559000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_100_11.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_100_11.png
# Iteration 11 completed in 70s
# Start Style Weight 1
# Start Content Weight 100
# Start of iteration 12
# Current loss value: 5355012600.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_100_12.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_100_12.png
# Iteration 12 completed in 71s
# Start Style Weight 1
# Start Content Weight 100
# Start of iteration 13
# Current loss value: 5276465000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_100_13.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_100_13.png
# Iteration 13 completed in 72s
# Start Style Weight 1
# Start Content Weight 100
# Start of iteration 14
# Current loss value: 5209485000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_100_14.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_100_14.png
# Iteration 14 completed in 74s
# Start Style Weight 1
# Start Content Weight 100
# Start of iteration 15
# Current loss value: 5150507500.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_100_15.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_100_15.png
# Iteration 15 completed in 75s
# Start Style Weight 1
# Start Content Weight 100
# Start of iteration 16
# Current loss value: 5096487000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_100_16.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_100_16.png
# Iteration 16 completed in 76s
# Start Style Weight 1
# Start Content Weight 100
# Start of iteration 17
# Current loss value: 5046615600.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_100_17.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_100_17.png
# Iteration 17 completed in 77s
# Start Style Weight 1
# Start Content Weight 100
# Start of iteration 18
# Current loss value: 5002483000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_100_18.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_100_18.png
# Iteration 18 completed in 79s
# Start Style Weight 1
# Start Content Weight 100
# Start of iteration 19
# Current loss value: 4961834500.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_100_19.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_1_100_19.png
# Iteration 19 completed in 80s
# Start Style Weight 100
# Start Content Weight 0
# Start of iteration 0
# Current loss value: 14303558000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_0_0.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_0_0.png
# Iteration 0 completed in 81s
# Start Style Weight 100
# Start Content Weight 0
# Start of iteration 1
# Current loss value: 7915001000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_0_1.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_0_1.png
# Iteration 1 completed in 82s
# Start Style Weight 100
# Start Content Weight 0
# Start of iteration 2
# Current loss value: 5836314000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_0_2.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_0_2.png
# Iteration 2 completed in 83s
# Start Style Weight 100
# Start Content Weight 0
# Start of iteration 3
# Current loss value: 4587548700.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_0_3.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_0_3.png
# Iteration 3 completed in 85s
# Start Style Weight 100
# Start Content Weight 0
# Start of iteration 4
# Current loss value: 4014431700.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_0_4.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_0_4.png
# Iteration 4 completed in 86s
# Start Style Weight 100
# Start Content Weight 0
# Start of iteration 5
# Current loss value: 3589275000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_0_5.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_0_5.png
# Iteration 5 completed in 87s
# Start Style Weight 100
# Start Content Weight 0
# Start of iteration 6
# Current loss value: 3313183700.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_0_6.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_0_6.png
# Iteration 6 completed in 89s
# Start Style Weight 100
# Start Content Weight 0
# Start of iteration 7
# Current loss value: 3037788700.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_0_7.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_0_7.png
# Iteration 7 completed in 90s
# Start Style Weight 100
# Start Content Weight 0
# Start of iteration 8
# Current loss value: 2814871600.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_0_8.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_0_8.png
# Iteration 8 completed in 91s
# Start Style Weight 100
# Start Content Weight 0
# Start of iteration 9
# Current loss value: 2648895000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_0_9.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_0_9.png
# Iteration 9 completed in 92s
# Start Style Weight 100
# Start Content Weight 0
# Start of iteration 10
# Current loss value: 2499958500.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_0_10.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_0_10.png
# Iteration 10 completed in 94s
# Start Style Weight 100
# Start Content Weight 0
# Start of iteration 11
# Current loss value: 2394708200.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_0_11.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_0_11.png
# Iteration 11 completed in 95s
# Start Style Weight 100
# Start Content Weight 0
# Start of iteration 12
# Current loss value: 2313397800.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_0_12.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_0_12.png
# Iteration 12 completed in 97s
# Start Style Weight 100
# Start Content Weight 0
# Start of iteration 13
# Current loss value: 2236227600.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_0_13.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_0_13.png
# Iteration 13 completed in 98s
# Start Style Weight 100
# Start Content Weight 0
# Start of iteration 14
# Current loss value: 2163726600.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_0_14.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_0_14.png
# Iteration 14 completed in 100s
# Start Style Weight 100
# Start Content Weight 0
# Start of iteration 15
# Current loss value: 2102845800.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_0_15.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_0_15.png
# Iteration 15 completed in 101s
# Start Style Weight 100
# Start Content Weight 0
# Start of iteration 16
# Current loss value: 2046910700.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_0_16.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_0_16.png
# Iteration 16 completed in 103s
# Start Style Weight 100
# Start Content Weight 0
# Start of iteration 17
# Current loss value: 1994604500.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_0_17.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_0_17.png
# Iteration 17 completed in 104s
# Start Style Weight 100
# Start Content Weight 0
# Start of iteration 18
# Current loss value: 1954132700.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_0_18.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_0_18.png
# Iteration 18 completed in 105s
# Start Style Weight 100
# Start Content Weight 0
# Start of iteration 19
# Current loss value: 1916325600.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_0_19.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_0_19.png
# Iteration 19 completed in 106s
# Start Style Weight 100
# Start Content Weight 1
# Start of iteration 0
# Current loss value: 3543465200.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_1_0.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_1_0.png
# Iteration 0 completed in 108s
# Start Style Weight 100
# Start Content Weight 1
# Start of iteration 1
# Current loss value: 3379690200.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_1_1.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_1_1.png
# Iteration 1 completed in 110s
# Start Style Weight 100
# Start Content Weight 1
# Start of iteration 2
# Current loss value: 3290599400.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_1_2.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_1_2.png
# Iteration 2 completed in 112s
# Start Style Weight 100
# Start Content Weight 1
# Start of iteration 3
# Current loss value: 3213607200.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_1_3.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_1_3.png
# Iteration 3 completed in 113s
# Start Style Weight 100
# Start Content Weight 1
# Start of iteration 4
# Current loss value: 3117947000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_1_4.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_1_4.png
# Iteration 4 completed in 115s
# Start Style Weight 100
# Start Content Weight 1
# Start of iteration 5
# Current loss value: 3060015900.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_1_5.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_1_5.png
# Iteration 5 completed in 116s
# Start Style Weight 100
# Start Content Weight 1
# Start of iteration 6
# Current loss value: 3011826700.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_1_6.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_1_6.png
# Iteration 6 completed in 118s
# Start Style Weight 100
# Start Content Weight 1
# Start of iteration 7
# Current loss value: 2967807000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_1_7.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_1_7.png
# Iteration 7 completed in 119s
# Start Style Weight 100
# Start Content Weight 1
# Start of iteration 8
# Current loss value: 2921911800.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_1_8.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_1_8.png
# Iteration 8 completed in 121s
# Start Style Weight 100
# Start Content Weight 1
# Start of iteration 9
# Current loss value: 2878467600.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_1_9.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_1_9.png
# Iteration 9 completed in 122s
# Start Style Weight 100
# Start Content Weight 1
# Start of iteration 10
# Current loss value: 2844692000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_1_10.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_1_10.png
# Iteration 10 completed in 124s
# Start Style Weight 100
# Start Content Weight 1
# Start of iteration 11
# Current loss value: 2816387600.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_1_11.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_1_11.png
# Iteration 11 completed in 126s
# Start Style Weight 100
# Start Content Weight 1
# Start of iteration 12
# Current loss value: 2772091000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_1_12.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_1_12.png
# Iteration 12 completed in 127s
# Start Style Weight 100
# Start Content Weight 1
# Start of iteration 13
# Current loss value: 2737281300.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_1_13.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_1_13.png
# Iteration 13 completed in 128s
# Start Style Weight 100
# Start Content Weight 1
# Start of iteration 14
# Current loss value: 2713345000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_1_14.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_1_14.png
# Iteration 14 completed in 130s
# Start Style Weight 100
# Start Content Weight 1
# Start of iteration 15
# Current loss value: 2691351800.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_1_15.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_1_15.png
# Iteration 15 completed in 132s
# Start Style Weight 100
# Start Content Weight 1
# Start of iteration 16
# Current loss value: 2672198700.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_1_16.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_1_16.png
# Iteration 16 completed in 134s
# Start Style Weight 100
# Start Content Weight 1
# Start of iteration 17
# Current loss value: 2645127700.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_1_17.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_1_17.png
# Iteration 17 completed in 135s
# Start Style Weight 100
# Start Content Weight 1
# Start of iteration 18
# Current loss value: 2622618600.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_1_18.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_1_18.png
# Iteration 18 completed in 137s
# Start Style Weight 100
# Start Content Weight 1
# Start of iteration 19
# Current loss value: 2601610200.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_1_19.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_1_19.png
# Iteration 19 completed in 139s
# Start Style Weight 100
# Start Content Weight 100
# Start of iteration 0
# Current loss value: 40461332000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_100_0.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_100_0.png
# Iteration 0 completed in 140s
# Start Style Weight 100
# Start Content Weight 100
# Start of iteration 1
# Current loss value: 31223978000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_100_1.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_100_1.png
# Iteration 1 completed in 143s
# Start Style Weight 100
# Start Content Weight 100
# Start of iteration 2
# Current loss value: 27735626000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_100_2.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_100_2.png
# Iteration 2 completed in 145s
# Start Style Weight 100
# Start Content Weight 100
# Start of iteration 3
# Current loss value: 25891738000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_100_3.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_100_3.png
# Iteration 3 completed in 146s
# Start Style Weight 100
# Start Content Weight 100
# Start of iteration 4
# Current loss value: 24690973000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_100_4.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_100_4.png
# Iteration 4 completed in 147s
# Start Style Weight 100
# Start Content Weight 100
# Start of iteration 5
# Current loss value: 23844598000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_100_5.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_100_5.png
# Iteration 5 completed in 152s
# Start Style Weight 100
# Start Content Weight 100
# Start of iteration 6
# Current loss value: 23250856000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_100_6.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_100_6.png
# Iteration 6 completed in 152s
# Start Style Weight 100
# Start Content Weight 100
# Start of iteration 7
# Current loss value: 22723455000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_100_7.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_100_7.png
# Iteration 7 completed in 155s
# Start Style Weight 100
# Start Content Weight 100
# Start of iteration 8
# Current loss value: 22393133000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_100_8.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_100_8.png
# Iteration 8 completed in 156s
# Start Style Weight 100
# Start Content Weight 100
# Start of iteration 9
# Current loss value: 22079990000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_100_9.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_100_9.png
# Iteration 9 completed in 157s
# Start Style Weight 100
# Start Content Weight 100
# Start of iteration 10
# Current loss value: 21792470000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_100_10.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_100_10.png
# Iteration 10 completed in 159s
# Start Style Weight 100
# Start Content Weight 100
# Start of iteration 11
# Current loss value: 21539502000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_100_11.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_100_11.png
# Iteration 11 completed in 161s
# Start Style Weight 100
# Start Content Weight 100
# Start of iteration 12
# Current loss value: 21322486000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_100_12.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_100_12.png
# Iteration 12 completed in 163s
# Start Style Weight 100
# Start Content Weight 100
# Start of iteration 13
# Current loss value: 21144328000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_100_13.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_100_13.png
# Iteration 13 completed in 164s
# Start Style Weight 100
# Start Content Weight 100
# Start of iteration 14
# Current loss value: 20955718000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_100_14.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_100_14.png
# Iteration 14 completed in 166s
# Start Style Weight 100
# Start Content Weight 100
# Start of iteration 15
# Current loss value: 20781408000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_100_15.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_100_15.png
# Iteration 15 completed in 168s
# Start Style Weight 100
# Start Content Weight 100
# Start of iteration 16
# Current loss value: 20647825000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_100_16.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_100_16.png
# Iteration 16 completed in 170s
# Start Style Weight 100
# Start Content Weight 100
# Start of iteration 17
# Current loss value: 20524378000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_100_17.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_100_17.png
# Iteration 17 completed in 172s
# Start Style Weight 100
# Start Content Weight 100
# Start of iteration 18
# Current loss value: 20423717000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_100_18.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_100_18.png
# Iteration 18 completed in 176s
# Start Style Weight 100
# Start Content Weight 100
# Start of iteration 19
# Current loss value: 20326154000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_100_19.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_8_2/salida_8_iteration_100_100_19.png
# Iteration 19 completed in 177s

# %% [markdown]
# # 9) Cambiar las imágenes de contenido y estilo por unas elegidas por usted. Adjuntar el resultado.
#
# Respuesta: Para este punto se utilizo la foto de Sol (perro raza Lebrel Whippet) y la pintura de Pablo Piccasso Les Demoiselles d'Avignon. Se realizo el mismo analisis que el solicitado en la pregunta 7 y 8.
# <img src="images\pregunta_9.jpeg">
#
# En este punto se realizo la iteracion con los parametros establecidos en la pregunta 7; y ademas se realizó la misma iteración que en la pregunta 9 sobre los pesos de estilo y contenido. En ambos casos se observan los mismos resulatdos mencionados con anticipación.

# %%
#Correr esto solo para pregunta 9
base_image_path = base_image_path_2
style_reference_image_path = style_reference_image_path_2

# %% [markdown]
# ### Primera iteracion con los parametros del comienzo
#
# <img src="images\pregunta_9_1.jpeg">

# %%
# !mkdir /output_9_1
result_prefix = Path("/output_9_1")



evaluator = Evaluator()
iterations = 100
# run scipy-based optimization (L-BFGS) over the pixels of the generated image
# so as to minimize the neural style loss
x = preprocess_image(base_image_path)

for i in range(iterations):
    print('Start of iteration', i)
    start_time = time.time()
    x, min_val, info = fmin_l_bfgs_b(evaluator.loss, x.flatten(),
                                     fprime=evaluator.grads, maxfun=20)
    print('Current loss value:', min_val)
    # save current generated image
    img = deprocess_image(x.copy())
    fname = result_prefix / ('sol_iteration_%d.png' % i)
    save_img(fname, img)
    end_time = time.time()
    print('Image saved as', fname)
    print('Iteration %d completed in %ds' % (i, end_time - start_time))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Start of iteration 0
# Current loss value: 16506997000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_0.png
# Iteration 0 completed in 18s
# Start of iteration 1
# Current loss value: 8292506600.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_1.png
# Iteration 1 completed in 9s
# Start of iteration 2
# Current loss value: 5570964500.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_2.png
# Iteration 2 completed in 9s
# Start of iteration 3
# Current loss value: 4429279000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_3.png
# Iteration 3 completed in 9s
# Start of iteration 4
# Current loss value: 3804252400.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_4.png
# Iteration 4 completed in 9s
# Start of iteration 5
# Current loss value: 3338514000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_5.png
# Iteration 5 completed in 9s
# Start of iteration 6
# Current loss value: 3036676400.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_6.png
# Iteration 6 completed in 9s
# Start of iteration 7
# Current loss value: 2827029200.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_7.png
# Iteration 7 completed in 9s
# Start of iteration 8
# Current loss value: 2624451600.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_8.png
# Iteration 8 completed in 9s
# Start of iteration 9
# Current loss value: 2474123000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_9.png
# Iteration 9 completed in 9s
# Start of iteration 10
# Current loss value: 2351357000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_10.png
# Iteration 10 completed in 9s
# Start of iteration 11
# Current loss value: 2237052400.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_11.png
# Iteration 11 completed in 9s
# Start of iteration 12
# Current loss value: 2151018500.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_12.png
# Iteration 12 completed in 9s
# Start of iteration 13
# Current loss value: 2050476400.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_13.png
# Iteration 13 completed in 9s
# Start of iteration 14
# Current loss value: 1972804500.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_14.png
# Iteration 14 completed in 9s
# Start of iteration 15
# Current loss value: 1892015600.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_15.png
# Iteration 15 completed in 9s
# Start of iteration 16
# Current loss value: 1822934100.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_16.png
# Iteration 16 completed in 9s
# Start of iteration 17
# Current loss value: 1740885500.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_17.png
# Iteration 17 completed in 9s
# Start of iteration 18
# Current loss value: 1681140000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_18.png
# Iteration 18 completed in 9s
# Start of iteration 19
# Current loss value: 1637822000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_19.png
# Iteration 19 completed in 9s
# Start of iteration 20
# Current loss value: 1598619600.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_20.png
# Iteration 20 completed in 9s
# Start of iteration 21
# Current loss value: 1565644400.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_21.png
# Iteration 21 completed in 9s
# Start of iteration 22
# Current loss value: 1535796200.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_22.png
# Iteration 22 completed in 9s
# Start of iteration 23
# Current loss value: 1506190700.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_23.png
# Iteration 23 completed in 11s
# Start of iteration 24
# Current loss value: 1477538800.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_24.png
# Iteration 24 completed in 9s
# Start of iteration 25
# Current loss value: 1443092200.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_25.png
# Iteration 25 completed in 9s
# Start of iteration 26
# Current loss value: 1414988800.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_26.png
# Iteration 26 completed in 9s
# Start of iteration 27
# Current loss value: 1391242500.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_27.png
# Iteration 27 completed in 9s
# Start of iteration 28
# Current loss value: 1369957800.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_28.png
# Iteration 28 completed in 9s
# Start of iteration 29
# Current loss value: 1351516400.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_29.png
# Iteration 29 completed in 9s
# Start of iteration 30
# Current loss value: 1328286700.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_30.png
# Iteration 30 completed in 9s
# Start of iteration 31
# Current loss value: 1304622100.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_31.png
# Iteration 31 completed in 9s
# Start of iteration 32
# Current loss value: 1289279700.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_32.png
# Iteration 32 completed in 9s
# Start of iteration 33
# Current loss value: 1274637800.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_33.png
# Iteration 33 completed in 9s
# Start of iteration 34
# Current loss value: 1254661600.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_34.png
# Iteration 34 completed in 9s
# Start of iteration 35
# Current loss value: 1235628400.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_35.png
# Iteration 35 completed in 9s
# Start of iteration 36
# Current loss value: 1213509400.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_36.png
# Iteration 36 completed in 9s
# Start of iteration 37
# Current loss value: 1194999600.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_37.png
# Iteration 37 completed in 9s
# Start of iteration 38
# Current loss value: 1179891100.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_38.png
# Iteration 38 completed in 9s
# Start of iteration 39
# Current loss value: 1168545300.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_39.png
# Iteration 39 completed in 9s
# Start of iteration 40
# Current loss value: 1155993300.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_40.png
# Iteration 40 completed in 9s
# Start of iteration 41
# Current loss value: 1146055300.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_41.png
# Iteration 41 completed in 9s
# Start of iteration 42
# Current loss value: 1132304100.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_42.png
# Iteration 42 completed in 9s
# Start of iteration 43
# Current loss value: 1120067000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_43.png
# Iteration 43 completed in 9s
# Start of iteration 44
# Current loss value: 1110663400.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_44.png
# Iteration 44 completed in 9s
# Start of iteration 45
# Current loss value: 1101883600.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_45.png
# Iteration 45 completed in 9s
# Start of iteration 46
# Current loss value: 1092711200.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_46.png
# Iteration 46 completed in 9s
# Start of iteration 47
# Current loss value: 1085198800.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_47.png
# Iteration 47 completed in 9s
# Start of iteration 48
# Current loss value: 1076435500.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_48.png
# Iteration 48 completed in 9s
# Start of iteration 49
# Current loss value: 1067916100.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_49.png
# Iteration 49 completed in 9s
# Start of iteration 50
# Current loss value: 1059049100.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_50.png
# Iteration 50 completed in 9s
# Start of iteration 51
# Current loss value: 1050974140.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_51.png
# Iteration 51 completed in 9s
# Start of iteration 52
# Current loss value: 1044758800.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_52.png
# Iteration 52 completed in 9s
# Start of iteration 53
# Current loss value: 1038710850.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_53.png
# Iteration 53 completed in 9s
# Start of iteration 54
# Current loss value: 1032352000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_54.png
# Iteration 54 completed in 9s
# Start of iteration 55
# Current loss value: 1025904000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_55.png
# Iteration 55 completed in 9s
# Start of iteration 56
# Current loss value: 1019747000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_56.png
# Iteration 56 completed in 9s
# Start of iteration 57
# Current loss value: 1012697340.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_57.png
# Iteration 57 completed in 9s
# Start of iteration 58
# Current loss value: 1007370430.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_58.png
# Iteration 58 completed in 9s
# Start of iteration 59
# Current loss value: 1001183360.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_59.png
# Iteration 59 completed in 9s
# Start of iteration 60
# Current loss value: 995021700.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_60.png
# Iteration 60 completed in 9s
# Start of iteration 61
# Current loss value: 990176500.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_61.png
# Iteration 61 completed in 9s
# Start of iteration 62
# Current loss value: 984652350.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_62.png
# Iteration 62 completed in 9s
# Start of iteration 63
# Current loss value: 979535000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_63.png
# Iteration 63 completed in 9s
# Start of iteration 64
# Current loss value: 974842000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_64.png
# Iteration 64 completed in 9s
# Start of iteration 65
# Current loss value: 970290800.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_65.png
# Iteration 65 completed in 9s
# Start of iteration 66
# Current loss value: 965040960.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_66.png
# Iteration 66 completed in 9s
# Start of iteration 67
# Current loss value: 961000200.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_67.png
# Iteration 67 completed in 9s
# Start of iteration 68
# Current loss value: 955759360.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_68.png
# Iteration 68 completed in 9s
# Start of iteration 69
# Current loss value: 950969000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_69.png
# Iteration 69 completed in 9s
# Start of iteration 70
# Current loss value: 946168960.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_70.png
# Iteration 70 completed in 9s
# Start of iteration 71
# Current loss value: 941804540.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_71.png
# Iteration 71 completed in 9s
# Start of iteration 72
# Current loss value: 937516350.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_72.png
# Iteration 72 completed in 9s
# Start of iteration 73
# Current loss value: 933362400.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_73.png
# Iteration 73 completed in 9s
# Start of iteration 74
# Current loss value: 929331200.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_74.png
# Iteration 74 completed in 9s
# Start of iteration 75
# Current loss value: 925553540.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_75.png
# Iteration 75 completed in 9s
# Start of iteration 76
# Current loss value: 921963400.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_76.png
# Iteration 76 completed in 9s
# Start of iteration 77
# Current loss value: 918367000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_77.png
# Iteration 77 completed in 9s
# Start of iteration 78
# Current loss value: 915009300.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_78.png
# Iteration 78 completed in 9s
# Start of iteration 79
# Current loss value: 911634300.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_79.png
# Iteration 79 completed in 9s
# Start of iteration 80
# Current loss value: 908133500.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_80.png
# Iteration 80 completed in 9s
# Start of iteration 81
# Current loss value: 904667300.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_81.png
# Iteration 81 completed in 9s
# Start of iteration 82
# Current loss value: 901315460.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_82.png
# Iteration 82 completed in 9s
# Start of iteration 83
# Current loss value: 897839740.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_83.png
# Iteration 83 completed in 9s
# Start of iteration 84
# Current loss value: 894557060.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_84.png
# Iteration 84 completed in 9s
# Start of iteration 85
# Current loss value: 891453630.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_85.png
# Iteration 85 completed in 9s
# Start of iteration 86
# Current loss value: 888675840.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_86.png
# Iteration 86 completed in 9s
# Start of iteration 87
# Current loss value: 885228540.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_87.png
# Iteration 87 completed in 9s
# Start of iteration 88
# Current loss value: 882103100.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_88.png
# Iteration 88 completed in 9s
# Start of iteration 89
# Current loss value: 879368770.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_89.png
# Iteration 89 completed in 9s
# Start of iteration 90
# Current loss value: 876231200.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_90.png
# Iteration 90 completed in 9s
# Start of iteration 91
# Current loss value: 873729540.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_91.png
# Iteration 91 completed in 9s
# Start of iteration 92
# Current loss value: 871242900.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_92.png
# Iteration 92 completed in 9s
# Start of iteration 93
# Current loss value: 868597250.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_93.png
# Iteration 93 completed in 9s
# Start of iteration 94
# Current loss value: 866140700.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_94.png
# Iteration 94 completed in 9s
# Start of iteration 95
# Current loss value: 863861100.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_95.png
# Iteration 95 completed in 9s
# Start of iteration 96
# Current loss value: 861637440.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_96.png
# Iteration 96 completed in 9s
# Start of iteration 97
# Current loss value: 859383550.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_97.png
# Iteration 97 completed in 9s
# Start of iteration 98
# Current loss value: 856907460.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_98.png
# Iteration 98 completed in 9s
# Start of iteration 99
# Current loss value: 854740200.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_1/sol_iteration_99.png
# Iteration 99 completed in 9s

# %% [markdown]
# ### Segunda iteración con las varaciones sobre los pesos de estilo y contenido
#
# <img src="images\pregunta_9_2.jpeg">

# %%
evaluator = Evaluator()
# Creamos el directorio para los archivos de salida
# !mkdir /output_9_2
result_prefix = Path("/output_9_2")



iterations =10
# run scipy-based optimization (L-BFGS) over the pixels of the generated image
# so as to minimize the neural style loss
x = preprocess_image(base_image_path)

for sw in [0,1,100]:
  style_weight = sw
  for cw in [0,1,100]:
    content_weight = cw
    for i in range(iterations):
      print('Start Style Weight', sw)
      print('Start Content Weight', cw) 
      print('Start of iteration', i)
      start_time = time.time()

      loss = K.variable(0.0)
      layer_features = outputs_dict['block5_conv2']
      base_image_features = layer_features[0, :, :, :]
      combination_features = layer_features[2, :, :, :]
      loss = loss + content_weight * content_loss(base_image_features,
                                              combination_features)
      feature_layers = ['block1_conv1', 'block2_conv1',
                    'block3_conv1', 'block4_conv1',
                    'block5_conv1']
      for layer_name in feature_layers:
        layer_features = outputs_dict[layer_name]
        style_reference_features = layer_features[1, :, :, :] 
        combination_features = layer_features[2, :, :, :]
        sl = style_loss(style_reference_features, combination_features)
        loss = loss + (style_weight / len(feature_layers)) * sl
      loss = loss + total_variation_weight * total_variation_loss(combination_image)

      grads = K.gradients(loss, combination_image)
      outputs = [loss]
      if isinstance(grads, (list, tuple)):
        outputs += grads
      else:
        outputs.append(grads)
      f_outputs = K.function([combination_image], outputs)

      x, min_val, info = fmin_l_bfgs_b(evaluator.loss, x.flatten(),
                                     fprime=evaluator.grads, maxfun=20)
      print('Current loss value:', min_val)
      # save current generated image
      img = deprocess_image(x.copy())
      fname = result_prefix / ('sol_iteration_%d_%d_%d.png' % (sw,cw,i))
      print('Image saved as', fname)
      save_img(fname, img)
      end_time = time.time()
      print('Image saved as', fname)
      print('Iteration %d completed in %ds' % (i, end_time - start_time))
# Out:
# mkdir: cannot create directory ‘/content/output/pesos/’: File exists
# Start Style Weight 0
# Start Content Weight 0
# Start of iteration 0
# Current loss value: 1823761.6
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_0_0.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_0_0.png
# Iteration 0 completed in 13s
# Start Style Weight 0
# Start Content Weight 0
# Start of iteration 1
# Current loss value: 396829.9
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_0_1.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_0_1.png
# Iteration 1 completed in 14s
# Start Style Weight 0
# Start Content Weight 0
# Start of iteration 2
# Current loss value: 178940.61
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_0_2.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_0_2.png
# Iteration 2 completed in 15s
# Start Style Weight 0
# Start Content Weight 0
# Start of iteration 3
# Current loss value: 111315.29
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_0_3.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_0_3.png
# Iteration 3 completed in 16s
# Start Style Weight 0
# Start Content Weight 0
# Start of iteration 4
# Current loss value: 77458.336
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_0_4.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_0_4.png
# Iteration 4 completed in 17s
# Start Style Weight 0
# Start Content Weight 0
# Start of iteration 5
# Current loss value: 57967.23
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_0_5.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_0_5.png
# Iteration 5 completed in 18s
# Start Style Weight 0
# Start Content Weight 0
# Start of iteration 6
# Current loss value: 46021.832
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_0_6.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_0_6.png
# Iteration 6 completed in 20s
# Start Style Weight 0
# Start Content Weight 0
# Start of iteration 7
# Current loss value: 38164.168
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_0_7.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_0_7.png
# Iteration 7 completed in 20s
# Start Style Weight 0
# Start Content Weight 0
# Start of iteration 8
# Current loss value: 32616.207
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_0_8.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_0_8.png
# Iteration 8 completed in 22s
# Start Style Weight 0
# Start Content Weight 0
# Start of iteration 9
# Current loss value: 28497.295
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_0_9.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_0_9.png
# Iteration 9 completed in 23s
# Start Style Weight 0
# Start Content Weight 1
# Start of iteration 0
# Current loss value: 149105840.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_1_0.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_1_0.png
# Iteration 0 completed in 24s
# Start Style Weight 0
# Start Content Weight 1
# Start of iteration 1
# Current loss value: 81214470.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_1_1.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_1_1.png
# Iteration 1 completed in 25s
# Start Style Weight 0
# Start Content Weight 1
# Start of iteration 2
# Current loss value: 58208230.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_1_2.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_1_2.png
# Iteration 2 completed in 26s
# Start Style Weight 0
# Start Content Weight 1
# Start of iteration 3
# Current loss value: 47538496.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_1_3.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_1_3.png
# Iteration 3 completed in 27s
# Start Style Weight 0
# Start Content Weight 1
# Start of iteration 4
# Current loss value: 41528176.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_1_4.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_1_4.png
# Iteration 4 completed in 28s
# Start Style Weight 0
# Start Content Weight 1
# Start of iteration 5
# Current loss value: 37645390.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_1_5.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_1_5.png
# Iteration 5 completed in 29s
# Start Style Weight 0
# Start Content Weight 1
# Start of iteration 6
# Current loss value: 35000990.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_1_6.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_1_6.png
# Iteration 6 completed in 31s
# Start Style Weight 0
# Start Content Weight 1
# Start of iteration 7
# Current loss value: 33097962.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_1_7.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_1_7.png
# Iteration 7 completed in 32s
# Start Style Weight 0
# Start Content Weight 1
# Start of iteration 8
# Current loss value: 31626076.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_1_8.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_1_8.png
# Iteration 8 completed in 33s
# Start Style Weight 0
# Start Content Weight 1
# Start of iteration 9
# Current loss value: 30394746.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_1_9.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_1_9.png
# Iteration 9 completed in 35s
# Start Style Weight 0
# Start Content Weight 100
# Start of iteration 0
# Current loss value: 1668277900.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_100_0.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_100_0.png
# Iteration 0 completed in 36s
# Start Style Weight 0
# Start Content Weight 100
# Start of iteration 1
# Current loss value: 1446627000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_100_1.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_100_1.png
# Iteration 1 completed in 38s
# Start Style Weight 0
# Start Content Weight 100
# Start of iteration 2
# Current loss value: 1305651100.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_100_2.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_100_2.png
# Iteration 2 completed in 39s
# Start Style Weight 0
# Start Content Weight 100
# Start of iteration 3
# Current loss value: 1202446700.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_100_3.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_100_3.png
# Iteration 3 completed in 40s
# Start Style Weight 0
# Start Content Weight 100
# Start of iteration 4
# Current loss value: 1125143200.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_100_4.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_100_4.png
# Iteration 4 completed in 41s
# Start Style Weight 0
# Start Content Weight 100
# Start of iteration 5
# Current loss value: 1056041200.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_100_5.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_100_5.png
# Iteration 5 completed in 42s
# Start Style Weight 0
# Start Content Weight 100
# Start of iteration 6
# Current loss value: 996946940.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_100_6.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_100_6.png
# Iteration 6 completed in 43s
# Start Style Weight 0
# Start Content Weight 100
# Start of iteration 7
# Current loss value: 944362900.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_100_7.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_100_7.png
# Iteration 7 completed in 45s
# Start Style Weight 0
# Start Content Weight 100
# Start of iteration 8
# Current loss value: 901954500.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_100_8.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_100_8.png
# Iteration 8 completed in 47s
# Start Style Weight 0
# Start Content Weight 100
# Start of iteration 9
# Current loss value: 865368500.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_100_9.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_0_100_9.png
# Iteration 9 completed in 49s
# Start Style Weight 1
# Start Content Weight 0
# Start of iteration 0
# Current loss value: 1560357800.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_0_0.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_0_0.png
# Iteration 0 completed in 48s
# Start Style Weight 1
# Start Content Weight 0
# Start of iteration 1
# Current loss value: 741686850.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_0_1.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_0_1.png
# Iteration 1 completed in 50s
# Start Style Weight 1
# Start Content Weight 0
# Start of iteration 2
# Current loss value: 551686600.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_0_2.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_0_2.png
# Iteration 2 completed in 51s
# Start Style Weight 1
# Start Content Weight 0
# Start of iteration 3
# Current loss value: 456801300.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_0_3.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_0_3.png
# Iteration 3 completed in 52s
# Start Style Weight 1
# Start Content Weight 0
# Start of iteration 4
# Current loss value: 402519360.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_0_4.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_0_4.png
# Iteration 4 completed in 53s
# Start Style Weight 1
# Start Content Weight 0
# Start of iteration 5
# Current loss value: 367994370.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_0_5.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_0_5.png
# Iteration 5 completed in 54s
# Start Style Weight 1
# Start Content Weight 0
# Start of iteration 6
# Current loss value: 340783000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_0_6.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_0_6.png
# Iteration 6 completed in 56s
# Start Style Weight 1
# Start Content Weight 0
# Start of iteration 7
# Current loss value: 318784060.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_0_7.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_0_7.png
# Iteration 7 completed in 57s
# Start Style Weight 1
# Start Content Weight 0
# Start of iteration 8
# Current loss value: 301389400.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_0_8.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_0_8.png
# Iteration 8 completed in 59s
# Start Style Weight 1
# Start Content Weight 0
# Start of iteration 9
# Current loss value: 285879600.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_0_9.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_0_9.png
# Iteration 9 completed in 61s
# Start Style Weight 1
# Start Content Weight 1
# Start of iteration 0
# Current loss value: 744911550.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_1_0.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_1_0.png
# Iteration 0 completed in 62s
# Start Style Weight 1
# Start Content Weight 1
# Start of iteration 1
# Current loss value: 664911200.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_1_1.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_1_1.png
# Iteration 1 completed in 63s
# Start Style Weight 1
# Start Content Weight 1
# Start of iteration 2
# Current loss value: 618629300.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_1_2.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_1_2.png
# Iteration 2 completed in 65s
# Start Style Weight 1
# Start Content Weight 1
# Start of iteration 3
# Current loss value: 589714900.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_1_3.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_1_3.png
# Iteration 3 completed in 67s
# Start Style Weight 1
# Start Content Weight 1
# Start of iteration 4
# Current loss value: 564799000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_1_4.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_1_4.png
# Iteration 4 completed in 68s
# Start Style Weight 1
# Start Content Weight 1
# Start of iteration 5
# Current loss value: 545081200.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_1_5.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_1_5.png
# Iteration 5 completed in 70s
# Start Style Weight 1
# Start Content Weight 1
# Start of iteration 6
# Current loss value: 530186560.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_1_6.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_1_6.png
# Iteration 6 completed in 71s
# Start Style Weight 1
# Start Content Weight 1
# Start of iteration 7
# Current loss value: 516948800.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_1_7.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_1_7.png
# Iteration 7 completed in 73s
# Start Style Weight 1
# Start Content Weight 1
# Start of iteration 8
# Current loss value: 506902460.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_1_8.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_1_8.png
# Iteration 8 completed in 75s
# Start Style Weight 1
# Start Content Weight 1
# Start of iteration 9
# Current loss value: 497261820.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_1_9.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_1_9.png
# Iteration 9 completed in 77s
# Start Style Weight 1
# Start Content Weight 100
# Start of iteration 0
# Current loss value: 14188682000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_100_0.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_100_0.png
# Iteration 0 completed in 78s
# Start Style Weight 1
# Start Content Weight 100
# Start of iteration 1
# Current loss value: 10921386000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_100_1.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_100_1.png
# Iteration 1 completed in 80s
# Start Style Weight 1
# Start Content Weight 100
# Start of iteration 2
# Current loss value: 9260135000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_100_2.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_100_2.png
# Iteration 2 completed in 81s
# Start Style Weight 1
# Start Content Weight 100
# Start of iteration 3
# Current loss value: 8274825700.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_100_3.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_100_3.png
# Iteration 3 completed in 83s
# Start Style Weight 1
# Start Content Weight 100
# Start of iteration 4
# Current loss value: 7653321000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_100_4.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_100_4.png
# Iteration 4 completed in 85s
# Start Style Weight 1
# Start Content Weight 100
# Start of iteration 5
# Current loss value: 7221509600.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_100_5.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_100_5.png
# Iteration 5 completed in 87s
# Start Style Weight 1
# Start Content Weight 100
# Start of iteration 6
# Current loss value: 6919995400.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_100_6.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_100_6.png
# Iteration 6 completed in 89s
# Start Style Weight 1
# Start Content Weight 100
# Start of iteration 7
# Current loss value: 6691968000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_100_7.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_100_7.png
# Iteration 7 completed in 90s
# Start Style Weight 1
# Start Content Weight 100
# Start of iteration 8
# Current loss value: 6510476300.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_100_8.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_100_8.png
# Iteration 8 completed in 92s
# Start Style Weight 1
# Start Content Weight 100
# Start of iteration 9
# Current loss value: 6365364700.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_100_9.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_1_100_9.png
# Iteration 9 completed in 94s
# Start Style Weight 100
# Start Content Weight 0
# Start of iteration 0
# Current loss value: 25834940000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_0_0.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_0_0.png
# Iteration 0 completed in 97s
# Start Style Weight 100
# Start Content Weight 0
# Start of iteration 1
# Current loss value: 16588428000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_0_1.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_0_1.png
# Iteration 1 completed in 98s
# Start Style Weight 100
# Start Content Weight 0
# Start of iteration 2
# Current loss value: 12925980000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_0_2.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_0_2.png
# Iteration 2 completed in 99s
# Start Style Weight 100
# Start Content Weight 0
# Start of iteration 3
# Current loss value: 11201808000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_0_3.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_0_3.png
# Iteration 3 completed in 102s
# Start Style Weight 100
# Start Content Weight 0
# Start of iteration 4
# Current loss value: 9814139000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_0_4.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_0_4.png
# Iteration 4 completed in 104s
# Start Style Weight 100
# Start Content Weight 0
# Start of iteration 5
# Current loss value: 8908056000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_0_5.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_0_5.png
# Iteration 5 completed in 105s
# Start Style Weight 100
# Start Content Weight 0
# Start of iteration 6
# Current loss value: 8218410500.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_0_6.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_0_6.png
# Iteration 6 completed in 108s
# Start Style Weight 100
# Start Content Weight 0
# Start of iteration 7
# Current loss value: 7642231000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_0_7.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_0_7.png
# Iteration 7 completed in 110s
# Start Style Weight 100
# Start Content Weight 0
# Start of iteration 8
# Current loss value: 7198009000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_0_8.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_0_8.png
# Iteration 8 completed in 112s
# Start Style Weight 100
# Start Content Weight 0
# Start of iteration 9
# Current loss value: 6851215400.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_0_9.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_0_9.png
# Iteration 9 completed in 113s
# Start Style Weight 100
# Start Content Weight 1
# Start of iteration 0
# Current loss value: 7246296000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_1_0.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_1_0.png
# Iteration 0 completed in 115s
# Start Style Weight 100
# Start Content Weight 1
# Start of iteration 1
# Current loss value: 6985514500.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_1_1.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_1_1.png
# Iteration 1 completed in 117s
# Start Style Weight 100
# Start Content Weight 1
# Start of iteration 2
# Current loss value: 6743268400.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_1_2.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_1_2.png
# Iteration 2 completed in 118s
# Start Style Weight 100
# Start Content Weight 1
# Start of iteration 3
# Current loss value: 6516150300.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_1_3.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_1_3.png
# Iteration 3 completed in 120s
# Start Style Weight 100
# Start Content Weight 1
# Start of iteration 4
# Current loss value: 6314068500.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_1_4.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_1_4.png
# Iteration 4 completed in 123s
# Start Style Weight 100
# Start Content Weight 1
# Start of iteration 5
# Current loss value: 6137713700.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_1_5.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_1_5.png
# Iteration 5 completed in 124s
# Start Style Weight 100
# Start Content Weight 1
# Start of iteration 6
# Current loss value: 5975805400.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_1_6.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_1_6.png
# Iteration 6 completed in 127s
# Start Style Weight 100
# Start Content Weight 1
# Start of iteration 7
# Current loss value: 5843548000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_1_7.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_1_7.png
# Iteration 7 completed in 129s
# Start Style Weight 100
# Start Content Weight 1
# Start of iteration 8
# Current loss value: 5718066000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_1_8.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_1_8.png
# Iteration 8 completed in 131s
# Start Style Weight 100
# Start Content Weight 1
# Start of iteration 9
# Current loss value: 5565510000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_1_9.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_1_9.png
# Iteration 9 completed in 133s
# Start Style Weight 100
# Start Content Weight 100
# Start of iteration 0
# Current loss value: 41055777000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_100_0.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_100_0.png
# Iteration 0 completed in 136s
# Start Style Weight 100
# Start Content Weight 100
# Start of iteration 1
# Current loss value: 35274187000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_100_1.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_100_1.png
# Iteration 1 completed in 138s
# Start Style Weight 100
# Start Content Weight 100
# Start of iteration 2
# Current loss value: 32328124000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_100_2.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_100_2.png
# Iteration 2 completed in 139s
# Start Style Weight 100
# Start Content Weight 100
# Start of iteration 3
# Current loss value: 30858037000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_100_3.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_100_3.png
# Iteration 3 completed in 142s
# Start Style Weight 100
# Start Content Weight 100
# Start of iteration 4
# Current loss value: 29566726000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_100_4.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_100_4.png
# Iteration 4 completed in 144s
# Start Style Weight 100
# Start Content Weight 100
# Start of iteration 5
# Current loss value: 28697928000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_100_5.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_100_5.png
# Iteration 5 completed in 146s
# Start Style Weight 100
# Start Content Weight 100
# Start of iteration 6
# Current loss value: 27991261000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_100_6.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_100_6.png
# Iteration 6 completed in 148s
# Start Style Weight 100
# Start Content Weight 100
# Start of iteration 7
# Current loss value: 27409347000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_100_7.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_100_7.png
# Iteration 7 completed in 150s
# Start Style Weight 100
# Start Content Weight 100
# Start of iteration 8
# Current loss value: 26896708000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_100_8.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_100_8.png
# Iteration 8 completed in 152s
# Start Style Weight 100
# Start Content Weight 100
# Start of iteration 9
# Current loss value: 26438654000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_100_9.png
# Image saved as /content/drive/My Drive/Colab Notebooks/Trabajo_Final/salida_9_2/sol_iteration_100_100_9.png
# Iteration 9 completed in 156s
